# %%
#1
alphabet = "abcdefghijklmnopqrstuvwxyz"

message = "xuo jxuhu! jxyi yi qd unqcfbu ev q squiqh syfxuh. muhu oek qrbu je tusetu yj? y xefu ie! iudt cu q cuiiqwu rqsa myjx jxu iqcu evviuj!"

translated_message = ""

for character in message:
  if character in alphabet:
    character_value = alphabet.find(character)
    translated_message += alphabet[(character_value + 10) % 26]
  else:
    translated_message += character

print(translated_message)

#2

message_for_v = "hey vishal! This is a super cool cipher, thanks for showing me! What else you got?"

translated_message_for_v = ""

for character in message_for_v:
  if character in alphabet:
    character_value = alphabet.find(character)
    translated_message_for_v += alphabet[(character_value - 10) % 26]
  else:
    translated_message_for_v += character
        
print(translated_message_for_v)

#3

def caesar_decode(message, offset):
    decoded_message = ""
    for character in message:
        if character in alphabet:
            new_pos = (alphabet.find(character) - offset) % 26
            decoded_message += alphabet[new_pos]
        else:
            decoded_message += character
    return decoded_message

def caesar_encode(message, offset):
    encoded_message = ""
    for character in message:
        if character in alphabet:
            new_pos = (alphabet.find(character) + offset) % 26
            encoded_message += alphabet[new_pos]
        else:
            encoded_message += character
    return encoded_message


print(caesar_decode("jxu evviuj veh jxu iusedt cuiiqwu yi vekhjuud.", 16))
print(caesar_decode("bqdradyuzs ygxfubxq omqemd oubtqde fa oapq kagd yqeemsqe ue qhqz yadq eqogdq!", 12))


#4
print(caesar_decode("vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl hulhexmx. px'ee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx.", 19))

#5

def vigenere_decode(cipher_text, keyword):
    decoded_message = ""
    keyword = keyword.lower()
    keyword_index = 0

    for char in cipher_text:
        if char.lower() in alphabet:
            shift = alphabet.index(keyword[keyword_index % len(keyword)])
            # NOTE: THIS IS THE IMPORTANT CHANGE: + shift
            new_index = (alphabet.index(char.lower()) + shift) % 26
            decoded_char = alphabet[new_index]

            # keep original capitalization
            if char.isupper():
                decoded_char = decoded_char.upper()

            decoded_message += decoded_char
            keyword_index += 1
        else:
            decoded_message += char  # keep spaces ? ! etc

    return decoded_message


cipher_text = "txm srom vkda gl lzlgzr qpdb? fepb ejac! ubr imn tapludwy mhfbz cza ruxzal wg zztylktoikqq!"
keyword = "friends"

decoded = vigenere_decode(cipher_text, keyword)
print(decoded)

#6 

def vigenere_encode(message, keyword):
    encoded_message = ""
    keyword = keyword.lower()
    keyword_index = 0

    for char in message:
        if char.lower() in alphabet:
            shift = alphabet.index(keyword[keyword_index % len(keyword)])
            # For encoding we shift forward
            new_index = (alphabet.index(char.lower()) + shift) % 26
            encoded_char = alphabet[new_index]
            if char.isupper():
                encoded_char = encoded_char.upper()
            encoded_message += encoded_char
            keyword_index += 1
        else:
            encoded_message += char
    return encoded_message;

message = "Hey Vishal! This cipher stuff is awesome, right?"
keyword = "friends"

encoded_message = vigenere_encode(message, keyword)

print("Encoded message:", encoded_message)
# Out:
# hey there! this is an example of a caesar cipher. were you able to decode it? i hope so! send me a message back with the same offset!
# xuo lyixqb! Txyi yi q ikfuh seeb syfxuh, jxqdai veh ixemydw cu! Wxqj ubiu oek wej?
# the offset for the second message is fourteen.
# performing multiple caesar ciphers to code your messages is even more secure!
# computers have rendered all of these old ciphers obsolete. we'll have to really step up our game if we want to keep our messages safe.
# you were able to decode this? nice work! you are becoming quite the expert at cryptography!
# Encoded message: Mvg Zvvzfc! Blvv ungpie vlzwn mf dojjwqr, ualyb?
